# %%
import pandas as pd
data = pd.read_csv('billboard.csv')
data
# Out:
#                  artiste                                  track genre  \
# 0        Destiny's Child               Independent Women Part I  Rock
# 1                Santana                           Maria, Maria  Rock
# 2          Savage Garden                     I Knew I Loved You  Rock
# 3                Madonna                                  Music  Rock
# 4    Aguilera, Christina  Come On Over Baby (All I Want Is You)  Rock
# ..                   ...                                    ...   ...
# 312     Ghostface Killah                       Cherchez LaGhost   R&B
# 313          Smith, Will                            Freakin' It   Rap
# 314        Zombie Nation                          Kernkraft 400  Rock
# 315       Eastsidaz, The                               Got Beef   Rap
# 316               Fragma                         Toca's Miracle   R&B
#
#     date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  x4th.week  \
# ...

# %%
columnsNamesArr = data.columns.values
columnsNamesArr
# Out:
# array(['artiste', 'track', 'genre', 'date.entered', 'date.peaked',
#        'x1st.week', 'x2nd.week', 'x3rd.week', 'x4th.week', 'x5th.week',
#        'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week', 'x10th.week',
#        'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week',
#        'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week',
#        'x19th.week', 'x20th.week', 'x21st.week', 'x22nd.week',
#        'x23rd.week', 'x24th.week', 'x25th.week', 'x26th.week',
#        'x27th.week', 'x28th.week', 'x29th.week', 'x30th.week',
#        'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week',
#        'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week',
#        'x39th.week', 'x40th.week', 'x41st.week', 'x42nd.week',
#        'x43rd.week', 'x44th.week', 'x45th.week', 'x46th.week',
#        'x47th.week', 'x48th.week', 'x49th.week', 'x50th.week',
#        'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week',
#        'x55th.week', 'x56th.week', 'x57th.week', 'x58th.week',
# ...

# %%
data.dtypes
# Out:
# artiste          object
# track            object
# genre            object
# date.entered     object
# date.peaked      object
#                  ...
# x72nd.week      float64
# x73rd.week      float64
# x74th.week      float64
# x75th.week      float64
# x76th.week      float64
# Length: 81, dtype: object

# %%
data['date.entered'] = pd.to_datetime(data['date.entered'])
data['date.peaked'] = pd.to_datetime(data['date.peaked'])
data.dtypes
# Out:
# artiste                 object
# track                   object
# genre                   object
# date.entered    datetime64[ns]
# date.peaked     datetime64[ns]
#                      ...
# x72nd.week             float64
# x73rd.week             float64
# x74th.week             float64
# x75th.week             float64
# x76th.week             float64
# Length: 81, dtype: object

# %%
df1 = pd.melt(data, id_vars=['artiste', 'track','genre','date.entered','date.peaked'], value_vars=['away_team', 'home_team'],
               value_name='team', var_name='home_away')

# %%
df2 = data.set_index(['artiste', 'track','genre','date.entered','date.peaked']).rename_axis(['Week'], axis=1).stack()

# %%
df2
# Out:
# artiste          track                     genre  date.entered  date.peaked  Week
# Destiny's Child  Independent Women Part I  Rock   2000-09-23    2000-11-18   x1st.week    78.0
#                                                                              x2nd.week    63.0
#                                                                              x3rd.week    49.0
#                                                                              x4th.week    33.0
#                                                                              x5th.week    23.0
#                                                                                           ...
# Zombie Nation    Kernkraft 400             Rock   2000-09-02    2000-09-02   x1st.week    99.0
#                                                                              x2nd.week    99.0
# Eastsidaz, The   Got Beef                  Rap    2000-07-01    2000-07-01   x1st.week    99.0
# ...
